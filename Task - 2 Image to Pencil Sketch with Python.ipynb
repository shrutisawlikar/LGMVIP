# %% [markdown]
# # Lets Grow More
#
# **Name: Shruti Sawlikar**
#
# **Task-2 : Image to Pencil Sketch with Python**

# %% [markdown]
# # Importing Libraries

# %%
import cv2
import matplotlib.pyplot as plt
plt.style.use("seaborn")

# %%
img = cv2.imread(r"C:\Users\hp\Pictures\Camera Roll\Elephant.jpg")
plt.figure(figsize=(8,8))
plt.axis("off")
plt.title("original image")
plt.imshow(img)

# %%
grey_img=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
plt.figure(figsize = (8,8))
plt.axis("off")
plt.title("original image")
plt.imshow(grey_img)

# %%
cv2.imwrite("sketch_grey_img.png",grey_img)
# Out:
# True

# %%
img_invert = cv2.bitwise_not(grey_img)
plt.figure(figsize = (8,8))
plt.axis("off")
plt.title("original image")
plt.imshow(img_invert)

# %%
cv2.imwrite("sketch_inverted_img.png",img_invert)
# Out:
# True

# %%
blur_img = cv2.GaussianBlur(invert,(21,21),0)
plt.figure(figsize = (8,8))
plt.axis("off"))
plt.title("original image")
plt.imshow(blur_img

# %%
cv2.imwrite("sketch_blur_img.png",blur_img)
# Out:
# True

# %%
inverted_blur=cv2.bitwise_not(blur_img)
plt.figure(figsize = (8,8))
plt.axis("off")
plt.title("original image")
plt.imshow(inverted_blur)

# %%
cv2.imwrite("sketch_inverted_blur_img.png",inverted_blur)
# Out:
# True

# %%
sketch = cv2.divide(grey_img,inverted_blur,scale=256.0)
plt.figure(figsize = (8,8))
plt.axis("off")
plt.title("original image")
plt.imshow(sketch)

# %%
cv2.imwrite("sketch.png",sketch)
# Out:
# True

# %% [markdown]
# # THANK YOU
